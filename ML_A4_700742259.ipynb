# %%
import pandas as pd
from google.colab import drive

#Loading the data into the drive 
drive.mount('/drive')
dataSet = pd.read_csv('/drive/MyDrive/data.csv')

# Showing basic statistical description of the data using the description() function
print(dataSet.describe())
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
# Checking if the data has null values or not 
dataSet.isnull().any()
# Out:
# Duration    False
# Pulse       False
# Maxpulse    False
# Calories     True
# dtype: bool

# %%
# 3.a)Replacing the null values with the mean function 
dataSet.fillna(dataSet.mean(), inplace=True)
dataSet.isnull().any()
# Out:
# Duration    False
# Pulse       False
# Maxpulse    False
# Calories    False
# dtype: bool

# %%
# Aggregating the data using min, max, count, and mean from data set 
agg_dataSet = dataSet[['Duration', 'Calories']].agg(['min', 'max', 'count', 'mean'])
print(agg_dataSet)
# Out:
#          Duration     Calories
# min     15.000000    50.300000
# max    300.000000  1860.400000
# count  169.000000   169.000000
# mean    63.846154   375.790244

# %%
# Filtering the dataframe to select rows with calories between 500 and 1000

filtered_dataSet = dataSet[(dataSet['Calories'] >= 500) & (dataSet['Calories'] <= 1000)]
print(filtered_dataSet)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 51         80    123       146     643.1
# 62        160    109       135     853.0
# 65        180     90       130     800.4
# 66        150    105       135     873.4
# 67        150    107       130     816.0
# 72         90    100       127     700.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 78        120    100       130     500.4
# 83        120    100       130     500.0
# 90        180    101       127     600.1
# 99         90     93       124     604.1
# 101        90     90       110     500.0
# 102        90     90       100     500.0
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %%
# Filtering the dataframe to select rows with calories > 500 and pulse < 100
filtered_dataSet2 = dataSet[(dataSet['Calories'] > 500) & (dataSet['Pulse'] < 100)]
print(filtered_dataSet2)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 65        180     90       130     800.4
# 70        150     97       129    1115.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 99         90     93       124     604.1
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %%
# Creating a new df_modified dataframe without Maxpulse column
dataSet_modified = dataSet.drop(columns=['Maxpulse'])

# Printing  the created new dataframe 
print(dataSet_modified)
# Out:
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# ..        ...    ...       ...
# 164        60    105     290.8
# 165        60    110     300.0
# 166        60    115     310.2
# 167        75    120     320.4
# 168        75    125     330.4
#
# [169 rows x 3 columns]

# %%
# Deleting Maxpulse column from the main dataframe
dataSet.drop(columns=['Maxpulse'], inplace=True)
print(dataSet)
# Out:
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# ..        ...    ...       ...
# 164        60    105     290.8
# 165        60    110     300.0
# 166        60    115     310.2
# 167        75    120     320.4
# 168        75    125     330.4
#
# [169 rows x 3 columns]

# %%
# Converting datatype of Calories column to int
dataSet['Calories'] = dataSet['Calories'].astype(int)
dataSet.dtypes
# Out:
# Duration    int64
# Pulse       int64
# Calories    int64
# dtype: object

# %%
# Creating scatter plot of Duration and Calories columns
dataSet.plot.scatter(x='Duration', y='Calories')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='Duration', ylabel='Calories'>

# %%
#Titanic DataSet
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Loading the dataset into the variable 
drive.mount('/drive')
titanic = pd.read_csv('/drive/MyDrive/train.csv')

#Converting Sex type
titanic['Sex'] = titanic['Sex'].replace(["female", "male"], [0, 1])

# Finding the correlation between 'survived' and 'sex'
corr = titanic['Survived'].corr(titanic['Sex'])

# Printing the correlation coefficient
print('Correlation between "survived" and "sex":', corr)

#Count plot showing the survival count by sex
sns.countplot(x='Survived', hue='Sex', data=titanic)
plt.title('Survival count by sex')
plt.show()

# Point plot showing the survival rate by sex
sns.pointplot(x='Sex', y='Survived', data=titanic)
plt.title('Survival rate by sex')
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).
# Correlation between "survived" and "sex": -0.5433513806577555
# Text(0.5, 1.0, 'Survival rate by sex')

# %%
#vizualization 1 
corr_data = titanic.corr()
sns.heatmap(corr_data ,cmap='Blues')
# Out:
# <Axes: >

# %%
#Visualization 2 
titanic.corr().style.background_gradient(cmap="Purples")
# Out:
# <style type="text/css">
# #T_bc18f_row0_col0, #T_bc18f_row1_col1, #T_bc18f_row2_col2, #T_bc18f_row3_col3, #T_bc18f_row4_col4, #T_bc18f_row5_col5, #T_bc18f_row6_col6, #T_bc18f_row7_col7 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_bc18f_row0_col1 {
#   background-color: #c2c3df;
#   color: #000000;
# }
# #T_bc18f_row0_col2, #T_bc18f_row5_col1 {
#   background-color: #c7c8e1;
#   color: #000000;
# }
# #T_bc18f_row0_col3 {
#   background-color: #bbbbdb;
#   color: #000000;
# }
# #T_bc18f_row0_col4 {
#   background-color: #cfd0e6;
#   color: #000000;
# }
# #T_bc18f_row0_col5, #T_bc18f_row6_col3 {
#   background-color: #e4e3f0;
#   color: #000000;
# }
# #T_bc18f_row0_col6 {
#   background-color: #e3e2ef;
#   color: #000000;
# }
# #T_bc18f_row0_col7 {
#   background-color: #bfc0de;
#   color: #000000;
# }
# #T_bc18f_row1_col0 {
#   background-color: #f7f6fa;
#   color: #000000;
# }
# #T_bc18f_row1_col2 {
#   background-color: #eeecf4;
#   color: #000000;
# }
# #T_bc18f_row1_col3, #T_bc18f_row2_col4, #T_bc18f_row2_col7, #T_bc18f_row3_col1, #T_bc18f_row3_col6, #T_bc18f_row4_col5, #T_bc18f_row5_col0, #T_bc18f_row7_col2 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_bc18f_row1_col4, #T_bc18f_row2_col6 {
#   background-color: #e0e0ee;
#   color: #000000;
# }
# #T_bc18f_row1_col5 {
#   background-color: #e1e0ee;
#   color: #000000;
# }
# #T_bc18f_row1_col6 {
#   background-color: #d7d7e9;
#   color: #000000;
# }
# #T_bc18f_row1_col7 {
#   background-color: #9995c6;
#   color: #f1f1f1;
# }
# #T_bc18f_row2_col0 {
#   background-color: #faf9fc;
#   color: #000000;
# }
# #T_bc18f_row2_col1, #T_bc18f_row6_col4 {
#   background-color: #eeecf5;
#   color: #000000;
# }
# #T_bc18f_row2_col3, #T_bc18f_row3_col2 {
#   background-color: #adabd2;
#   color: #000000;
# }
# #T_bc18f_row2_col5 {
#   background-color: #cecfe5;
#   color: #000000;
# }
# #T_bc18f_row3_col0 {
#   background-color: #f2f0f7;
#   color: #000000;
# }
# #T_bc18f_row3_col4, #T_bc18f_row7_col4 {
#   background-color: #c5c6e1;
#   color: #000000;
# }
# #T_bc18f_row3_col5 {
#   background-color: #eceaf3;
#   color: #000000;
# }
# #T_bc18f_row3_col7 {
#   background-color: #dcdcec;
#   color: #000000;
# }
# #T_bc18f_row4_col0 {
#   background-color: #f3f1f7;
#   color: #000000;
# }
# #T_bc18f_row4_col1 {
#   background-color: #cecee5;
#   color: #000000;
# }
# #T_bc18f_row4_col2 {
#   background-color: #f0eef6;
#   color: #000000;
# }
# #T_bc18f_row4_col3 {
#   background-color: #b3b3d6;
#   color: #000000;
# }
# #T_bc18f_row4_col6, #T_bc18f_row5_col4 {
#   background-color: #f8f6fa;
#   color: #000000;
# }
# #T_bc18f_row4_col7 {
#   background-color: #b2b2d5;
#   color: #000000;
# }
# #T_bc18f_row5_col2 {
#   background-color: #b4b4d7;
#   color: #000000;
# }
# #T_bc18f_row5_col3 {
#   background-color: #d3d3e8;
#   color: #000000;
# }
# #T_bc18f_row5_col6 {
#   background-color: #9793c5;
#   color: #f1f1f1;
# }
# #T_bc18f_row5_col7 {
#   background-color: #a8a6cf;
#   color: #f1f1f1;
# }
# #T_bc18f_row6_col0 {
#   background-color: #f7f5fa;
#   color: #000000;
# }
# #T_bc18f_row6_col1 {
#   background-color: #b5b5d7;
#   color: #000000;
# }
# #T_bc18f_row6_col2 {
#   background-color: #bebfdd;
#   color: #000000;
# }
# #T_bc18f_row6_col5 {
#   background-color: #918ec2;
#   color: #f1f1f1;
# }
# #T_bc18f_row6_col7 {
#   background-color: #9f9cc9;
#   color: #f1f1f1;
# }
# #T_bc18f_row7_col0 {
#   background-color: #f5f4f9;
#   color: #000000;
# }
# #T_bc18f_row7_col1 {
#   background-color: #9a96c6;
#   color: #f1f1f1;
# }
# #T_bc18f_row7_col3 {
#   background-color: #ddddec;
#   color: #000000;
# }
# #T_bc18f_row7_col5 {
#   background-color: #c0c1de;
#   color: #000000;
# }
# #T_bc18f_row7_col6 {
#   background-color: #bebedd;
#   color: #000000;
# }
# </style>
# <table id="T_bc18f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc18f_level0_col0" class="col_heading level0 col0" >PassengerId</th>
#       <th id="T_bc18f_level0_col1" class="col_heading level0 col1" >Survived</th>
#       <th id="T_bc18f_level0_col2" class="col_heading level0 col2" >Pclass</th>
#       <th id="T_bc18f_level0_col3" class="col_heading level0 col3" >Sex</th>
#       <th id="T_bc18f_level0_col4" class="col_heading level0 col4" >Age</th>
#       <th id="T_bc18f_level0_col5" class="col_heading level0 col5" >SibSp</th>
#       <th id="T_bc18f_level0_col6" class="col_heading level0 col6" >Parch</th>
#       <th id="T_bc18f_level0_col7" class="col_heading level0 col7" >Fare</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc18f_level0_row0" class="row_heading level0 row0" >PassengerId</th>
#       <td id="T_bc18f_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_bc18f_row0_col1" class="data row0 col1" >-0.005007</td>
#       <td id="T_bc18f_row0_col2" class="data row0 col2" >-0.035144</td>
#       <td id="T_bc18f_row0_col3" class="data row0 col3" >0.042939</td>
#       <td id="T_bc18f_row0_col4" class="data row0 col4" >0.036847</td>
#       <td id="T_bc18f_row0_col5" class="data row0 col5" >-0.057527</td>
#       <td id="T_bc18f_row0_col6" class="data row0 col6" >-0.001652</td>
#       <td id="T_bc18f_row0_col7" class="data row0 col7" >0.012658</td>
#     </tr>
#     <tr>
#       <th id="T_bc18f_level0_row1" class="row_heading level0 row1" >Survived</th>
#       <td id="T_bc18f_row1_col0" class="data row1 col0" >-0.005007</td>
#       <td id="T_bc18f_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_bc18f_row1_col2" class="data row1 col2" >-0.338481</td>
#       <td id="T_bc18f_row1_col3" class="data row1 col3" >-0.543351</td>
#       <td id="T_bc18f_row1_col4" class="data row1 col4" >-0.077221</td>
#       <td id="T_bc18f_row1_col5" class="data row1 col5" >-0.035322</td>
#       <td id="T_bc18f_row1_col6" class="data row1 col6" >0.081629</td>
#       <td id="T_bc18f_row1_col7" class="data row1 col7" >0.257307</td>
#     </tr>
#     <tr>
#       <th id="T_bc18f_level0_row2" class="row_heading level0 row2" >Pclass</th>
#       <td id="T_bc18f_row2_col0" class="data row2 col0" >-0.035144</td>
#       <td id="T_bc18f_row2_col1" class="data row2 col1" >-0.338481</td>
#       <td id="T_bc18f_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_bc18f_row2_col3" class="data row2 col3" >0.131900</td>
#       <td id="T_bc18f_row2_col4" class="data row2 col4" >-0.369226</td>
#       <td id="T_bc18f_row2_col5" class="data row2 col5" >0.083081</td>
#       <td id="T_bc18f_row2_col6" class="data row2 col6" >0.018443</td>
#       <td id="T_bc18f_row2_col7" class="data row2 col7" >-0.549500</td>
#     </tr>
#     <tr>
#       <th id="T_bc18f_level0_row3" class="row_heading level0 row3" >Sex</th>
#       <td id="T_bc18f_row3_col0" class="data row3 col0" >0.042939</td>
#       <td id="T_bc18f_row3_col1" class="data row3 col1" >-0.543351</td>
#       <td id="T_bc18f_row3_col2" class="data row3 col2" >0.131900</td>
#       <td id="T_bc18f_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_bc18f_row3_col4" class="data row3 col4" >0.093254</td>
#       <td id="T_bc18f_row3_col5" class="data row3 col5" >-0.114631</td>
#       <td id="T_bc18f_row3_col6" class="data row3 col6" >-0.245489</td>
#       <td id="T_bc18f_row3_col7" class="data row3 col7" >-0.182333</td>
#     </tr>
#     <tr>
#       <th id="T_bc18f_level0_row4" class="row_heading level0 row4" >Age</th>
#       <td id="T_bc18f_row4_col0" class="data row4 col0" >0.036847</td>
#       <td id="T_bc18f_row4_col1" class="data row4 col1" >-0.077221</td>
#       <td id="T_bc18f_row4_col2" class="data row4 col2" >-0.369226</td>
#       <td id="T_bc18f_row4_col3" class="data row4 col3" >0.093254</td>
#       <td id="T_bc18f_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_bc18f_row4_col5" class="data row4 col5" >-0.308247</td>
#       <td id="T_bc18f_row4_col6" class="data row4 col6" >-0.189119</td>
#       <td id="T_bc18f_row4_col7" class="data row4 col7" >0.096067</td>
#     </tr>
#     <tr>
#       <th id="T_bc18f_level0_row5" class="row_heading level0 row5" >SibSp</th>
#       <td id="T_bc18f_row5_col0" class="data row5 col0" >-0.057527</td>
#       <td id="T_bc18f_row5_col1" class="data row5 col1" >-0.035322</td>
#       <td id="T_bc18f_row5_col2" class="data row5 col2" >0.083081</td>
#       <td id="T_bc18f_row5_col3" class="data row5 col3" >-0.114631</td>
#       <td id="T_bc18f_row5_col4" cl

# %%
# Implementing the Naive's Bayes
import pandas as pd
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Load Titanic dataset
drive.mount('/drive')
titanic = pd.read_csv('/drive/MyDrive/train.csv')

# Prepare data for the values of 'sex' 'age'
X = titanic[['Sex', 'Age']]
X['Sex'] = X['Sex'].map({'male': 0, 'female': 1})  # Convert 'sex' to binary
X = X.fillna(X.mean())  # Replace missing values with mean
y = titanic['Survived']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train Naive Bayes classifier
gnb = GaussianNB()
gnb.fit(X_train, y_train)

# Make predictions on testing set
y_pred = gnb.predict(X_test)

# Calculate accuracy for the dataset values
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy:', accuracy)
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).
# Accuracy: 0.7910447761194029
# <ipython-input-82-25657b423454>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Sex'] = X['Sex'].map({'male': 0, 'female': 1})  # Convert 'sex' to binary

# %%
#Glass DataSet Classifier 
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report

# Load the glass dataset using pandas
glass = pd.read_csv("/drive/MyDrive/glass.csv")

# Extract the features and target variable
X = glass.drop("Type", axis=1).values
y = glass["Type"].values

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7)

# Create a Gaussian Naive Bayes classifier
clf_nb = GaussianNB()

# Train the classifier on the training data
clf_nb.fit(X_train, y_train)

# Predict the class labels for the testing data
y_pred_nb = clf_nb.predict(X_test)

# Evaluate the classifier's performance on the testing data
score_nb = clf_nb.score(X_test, y_test)
print("Naive Bayes Accuracy:", score_nb)

report_nb = classification_report(y_test, y_pred_nb)
print(report_nb)
# Out:
# Naive Bayes Accuracy: 0.20930232558139536
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        10
#            2       0.57      0.18      0.28        22
#            3       0.00      0.00      0.00         3
#            5       0.00      0.00      0.00         2
#            6       0.00      0.00      0.00         1
#            7       0.83      1.00      0.91         5
#
#     accuracy                           0.21        43
#    macro avg       0.23      0.20      0.20        43
# weighted avg       0.39      0.21      0.25        43

# %%
# Create a linear SVM classifier
clf_svm = LinearSVC()

# Train the classifier on the training data
clf_svm.fit(X_train, y_train)

# Predict the class labels for the testing data
y_pred_svm = clf_svm.predict(X_test)

# Evaluate the classifier's performance on the testing data
score_svm = clf_svm.score(X_test, y_test)
print("Linear SVM Accuracy:", score_svm)

report_svm = classification_report(y_test, y_pred_svm)
print(report_svm)
# Out:
# Linear SVM Accuracy: 0.3953488372093023
#               precision    recall  f1-score   support
#
#            1       0.32      1.00      0.49        10
#            2       0.00      0.00      0.00        22
#            3       0.00      0.00      0.00         3
#            5       0.40      1.00      0.57         2
#            6       0.00      0.00      0.00         1
#            7       0.83      1.00      0.91         5
#
#     accuracy                           0.40        43
#    macro avg       0.26      0.50      0.33        43
# weighted avg       0.19      0.40      0.25        43
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Do at least two visualizations to describe or show correlations in the Glass Dataset. 
correlation_data = glass.corr()
sns.heatmap(correlation_data,cmap='coolwarm')
# Out:
# <Axes: >

# %%
 #visualization 2
 glass.corr().style.background_gradient(cmap="Greens_r")
# Out:
# <style type="text/css">
# #T_2c2dd_row0_col0, #T_2c2dd_row1_col1, #T_2c2dd_row2_col2, #T_2c2dd_row3_col3, #T_2c2dd_row4_col4, #T_2c2dd_row5_col5, #T_2c2dd_row6_col6, #T_2c2dd_row7_col7, #T_2c2dd_row8_col8, #T_2c2dd_row9_col9 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_2c2dd_row0_col1 {
#   background-color: #005924;
#   color: #f1f1f1;
# }
# #T_2c2dd_row0_col2 {
#   background-color: #3da65a;
#   color: #f1f1f1;
# }
# #T_2c2dd_row0_col3 {
#   background-color: #005321;
#   color: #f1f1f1;
# }
# #T_2c2dd_row0_col4, #T_2c2dd_row1_col8, #T_2c2dd_row2_col1, #T_2c2dd_row2_col3, #T_2c2dd_row2_col6, #T_2c2dd_row2_col7, #T_2c2dd_row2_col9, #T_2c2dd_row4_col0, #T_2c2dd_row6_col1, #T_2c2dd_row6_col5, #T_2c2dd_row9_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_2c2dd_row0_col5 {
#   background-color: #004a1e;
#   color: #f1f1f1;
# }
# #T_2c2dd_row0_col6 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_2c2dd_row0_col7, #T_2c2dd_row4_col2 {
#   background-color: #369f54;
#   color: #f1f1f1;
# }
# #T_2c2dd_row0_col8 {
#   background-color: #319a50;
#   color: #f1f1f1;
# }
# #T_2c2dd_row0_col9 {
#   background-color: #37a055;
#   color: #f1f1f1;
# }
# #T_2c2dd_row1_col0, #T_2c2dd_row7_col6 {
#   background-color: #1d8640;
#   color: #f1f1f1;
# }
# #T_2c2dd_row1_col2, #T_2c2dd_row2_col0 {
#   background-color: #289049;
#   color: #f1f1f1;
# }
# #T_2c2dd_row1_col3, #T_2c2dd_row5_col2 {
#   background-color: #58b668;
#   color: #f1f1f1;
# }
# #T_2c2dd_row1_col4, #T_2c2dd_row9_col6 {
#   background-color: #309950;
#   color: #f1f1f1;
# }
# #T_2c2dd_row1_col5, #T_2c2dd_row9_col8 {
#   background-color: #005120;
#   color: #f1f1f1;
# }
# #T_2c2dd_row1_col6 {
#   background-color: #00692a;
#   color: #f1f1f1;
# }
# #T_2c2dd_row1_col7 {
#   background-color: #86cc85;
#   color: #000000;
# }
# #T_2c2dd_row1_col9, #T_2c2dd_row9_col7 {
#   background-color: #bde5b6;
#   color: #000000;
# }
# #T_2c2dd_row2_col4, #T_2c2dd_row2_col5, #T_2c2dd_row9_col0 {
#   background-color: #218944;
#   color: #f1f1f1;
# }
# #T_2c2dd_row2_col8, #T_2c2dd_row4_col7 {
#   background-color: #258d47;
#   color: #f1f1f1;
# }
# #T_2c2dd_row3_col0, #T_2c2dd_row5_col6 {
#   background-color: #006027;
#   color: #f1f1f1;
# }
# #T_2c2dd_row3_col1 {
#   background-color: #38a156;
#   color: #f1f1f1;
# }
# #T_2c2dd_row3_col2, #T_2c2dd_row6_col3 {
#   background-color: #077331;
#   color: #f1f1f1;
# }
# #T_2c2dd_row3_col4, #T_2c2dd_row7_col0 {
#   background-color: #3ba458;
#   color: #f1f1f1;
# }
# #T_2c2dd_row3_col5 {
#   background-color: #70c274;
#   color: #000000;
# }
# #T_2c2dd_row3_col6 {
#   background-color: #006d2c;
#   color: #f1f1f1;
# }
# #T_2c2dd_row3_col7, #T_2c2dd_row7_col3 {
#   background-color: #a9dca3;
#   color: #000000;
# }
# #T_2c2dd_row3_col8 {
#   background-color: #026f2e;
#   color: #f1f1f1;
# }
# #T_2c2dd_row3_col9 {
#   background-color: #ccebc6;
#   color: #000000;
# }
# #T_2c2dd_row4_col1, #T_2c2dd_row4_col6, #T_2c2dd_row5_col0 {
#   background-color: #0a7633;
#   color: #f1f1f1;
# }
# #T_2c2dd_row4_col3 {
#   background-color: #349d53;
#   color: #f1f1f1;
# }
# #T_2c2dd_row4_col5 {
#   background-color: #006328;
#   color: #f1f1f1;
# }
# #T_2c2dd_row4_col8 {
#   background-color: #006b2b;
#   color: #f1f1f1;
# }
# #T_2c2dd_row4_col9 {
#   background-color: #79c67a;
#   color: #000000;
# }
# #T_2c2dd_row5_col1 {
#   background-color: #00451c;
#   color: #f1f1f1;
# }
# #T_2c2dd_row5_col3 {
#   background-color: #84cc83;
#   color: #000000;
# }
# #T_2c2dd_row5_col4 {
#   background-color: #1c8540;
#   color: #f1f1f1;
# }
# #T_2c2dd_row5_col7 {
#   background-color: #2f984f;
#   color: #f1f1f1;
# }
# #T_2c2dd_row5_col8 {
#   background-color: #127c39;
#   color: #f1f1f1;
# }
# #T_2c2dd_row5_col9 {
#   background-color: #53b466;
#   color: #f1f1f1;
# }
# #T_2c2dd_row6_col0 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_2c2dd_row6_col2 {
#   background-color: #0d7836;
#   color: #f1f1f1;
# }
# #T_2c2dd_row6_col4 {
#   background-color: #19833e;
#   color: #f1f1f1;
# }
# #T_2c2dd_row6_col7 {
#   background-color: #248c46;
#   color: #f1f1f1;
# }
# #T_2c2dd_row6_col8 {
#   background-color: #2e964d;
#   color: #f1f1f1;
# }
# #T_2c2dd_row6_col9 {
#   background-color: #56b567;
#   color: #f1f1f1;
# }
# #T_2c2dd_row7_col1 {
#   background-color: #68be70;
#   color: #000000;
# }
# #T_2c2dd_row7_col2, #T_2c2dd_row7_col8 {
#   background-color: #067230;
#   color: #f1f1f1;
# }
# #T_2c2dd_row7_col4 {
#   background-color: #2c944c;
#   color: #f1f1f1;
# }
# #T_2c2dd_row7_col5 {
#   background-color: #17813d;
#   color: #f1f1f1;
# }
# #T_2c2dd_row7_col9 {
#   background-color: #c9eac2;
#   color: #000000;
# }
# #T_2c2dd_row8_col0 {
#   background-color: #5db96b;
#   color: #f1f1f1;
# }
# #T_2c2dd_row8_col1 {
#   background-color: #004c1e;
#   color: #f1f1f1;
# }
# #T_2c2dd_row8_col2 {
#   background-color: #6abf71;
#   color: #000000;
# }
# #T_2c2dd_row8_col3 {
#   background-color: #29914a;
#   color: #f1f1f1;
# }
# #T_2c2dd_row8_col4, #T_2c2dd_row8_col7 {
#   background-color: #2d954d;
#   color: #f1f1f1;
# }
# #T_2c2dd_row8_col5 {
#   background-color: #1f8742;
#   color: #f1f1f1;
# }
# #T_2c2dd_row8_col6 {
#   background-color: #48ae60;
#   color: #f1f1f1;
# }
# #T_2c2dd_row8_col9 {
#   background-color: #339c52;
#   color: #f1f1f1;
# }
# #T_2c2dd_row9_col1 {
#   background-color: #9cd797;
#   color: #000000;
# }
# #T_2c2dd_row9_col3 {
#   background-color: #c1e6ba;
#   color: #000000;
# }
# #T_2c2dd_row9_col4 {
#   background-color: #60ba6c;
#   color: #f1f1f1;
# }
# #T_2c2dd_row9_col5 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2c2dd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c2dd_level0_col0" class="col_heading level0 col0" >RI</th>
#       <th id="T_2c2dd_level0_col1" class="col_heading level0 col1" >Na</th>
#       <th id="T_2c2dd_level0_col2" class="col_heading level0 col2" >Mg</th>
#       <th id="T_2c2dd_level0_col3" class="col_heading level0 col3" >Al</th>
#       <th id="T_2c2dd_level0_col4" class="col_heading level0 col4" >Si</th>
#       <th id="T_2c2dd_level0_col5" class="col_heading level0 col5" >K</th>
#       <th id="T_2c2dd_level0_col6" class="col_heading level0 col6" >Ca</th>
#       <th id="T_2c2dd_level0_col7" class="col_heading level0 col7" >Ba</th>
#       <th id="T_2c2dd_level0_col8" class="col_heading level0 col8" >Fe</th>
#       <th id="T_2c2dd_level0_col9" class="col_heading level0 col9" >Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c2dd_level0_row0" class="row_heading level0 row0" >RI</th>
#       <td id="T_2c2dd_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_2c2dd_row0_col1" class="data row0 col1" >-0.191885</td>
#       <td id="T_2c2dd_row0_col2" class="data row0 col2" >-0.122274</td>
#       <td id="T_2c2dd_row0_col3" class="data row0 col3" >-0.407326</td>
#       <td id="T_2c2dd_row0_col4" class="data row0 col4" >-0.542052</td>
#       <td id="T_2c2dd_row0_col5" class="data row0 col5" >-0.289833</td>
#       <td id="T_2c2dd_row0_col6" class="data row0 col6" >0.810403</td>
#       <td id="T_2c2dd_row0_col7" class="data row0 col7" >-0.000386</td>
#       <td id="T_2c2dd_row0_col8" class="data row0 col8" >0.143010</td>
#       <td id="T_2c2dd_row0_col9" class="data row0 col9" >-0.164237</td>
#     </tr>
#     <tr>
#       <th id="T_2c2dd_level0_row1" class="row_heading level0 row1" >Na</th>
#       <td id="T_2c2dd_row1_col0" class="data row1 col0" >-0.191885</td>
#       <td id="T_2c2dd_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_2c2dd_row1_col2" class="data row1 col2" >-0.273732</td>
#       <td id="T_2c2dd_row1_col3" class="data row1 col3" >0.156794</td>
#       <td id="T_2c2dd_row1_col4" class="data row1 col4" >-0.069809</td>
#       <td id="T_2c2dd_row1_col5" class="data row1 col5" >-0.266087</td>
#       <td id="T_2c2dd_row1_col6" class="data row1 col6" >-0.275442</td>
#       <td id="T_2c2dd_row1_col7" class="data row1 col7" >0.326603</td>
#       <td id="T_2c2dd_row1_col8" class="data row1 col8" >-0.241346</td>
#       <td id="T_2c2dd_row1_col9" class="data row1 col9" >0.502898</td>
#     </tr>
#     <tr>
#       <th id="T_2c2dd_level0_row2" class="row_heading level0 row2" >Mg</th>
#       <td id="T_2c2dd_row2_col0" class="data row2 col0" >-0.122274</td>
#       <td id="T_2c2dd_row2_col1" class="data row2 col1" >-0.273732</td>
#       <td id="T_2c2dd_row2_col2" class="data row2 col2" >1.000000</td>
